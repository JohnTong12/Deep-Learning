# %%
### seeding for reproducibility
import random
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
random.seed(0)
import tensorflow as tf
tf.random.set_seed(0)

# %%
### Configuring the Path for the Kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
# 100% 810M/812M [00:36<00:00, 23.0MB/s]
# 100% 812M/812M [00:36<00:00, 23.2MB/s]

# %%
# !ls
# Out:
# dogs-vs-cats.zip  drive  kaggle.json  sample_data

# %%
## importing some librarries
import os
from zipfile  import ZipFile

# %%
### unzipping the dataset
dataset =  '/content/dogs-vs-cats.zip'
with ZipFile (dataset  , 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
### Unzipping the train data
dataset =  '/content/train.zip'
with ZipFile (dataset  , 'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
# !ls
# Out:
# dogs-vs-cats.zip  kaggle.json  sampleSubmission.csv  train
# drive		  sample_data  test1.zip	     train.zip

# %%
## checking the train directory
print('-------------The train directorty----------------')
print(len(os.listdir('/content/train')))
print(os.listdir('/content/train')[:5])
print(os.listdir('/content/train')[-5:])
# Out:
# -------------The train directorty----------------
# 25000
# ['cat.4838.jpg', 'dog.3125.jpg', 'cat.4932.jpg', 'dog.11075.jpg', 'cat.8369.jpg']
# ['cat.3092.jpg', 'cat.9856.jpg', 'cat.7663.jpg', 'dog.8469.jpg', 'dog.9782.jpg']

# %%
### checking how many images of cats and digs are there
filenames =    os.listdir('/content/train')
for file
